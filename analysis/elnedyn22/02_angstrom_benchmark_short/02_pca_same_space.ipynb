# %%
# !pwd
# Out:
# /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22

# %% [markdown]
# # Essential dynamics on BB using all trajectories

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
#
# mkdir -p pca
#
# gmx trjcat -f \
# ./4zw9/0.025nm/rep1/step7_production_rep1.xtc \
# ./4zw9/0.025nm/rep2/step7_production_rep2.xtc \
# ./4zw9/0.025nm/rep3/step7_production_rep3.xtc \
# ./4zw9/0.01nm/rep1/step7_production_rep1.xtc \
# ./4zw9/0.01nm/rep2/step7_production_rep2.xtc \
# ./4zw9/0.01nm/rep3/step7_production_rep3.xtc \
# ./4zw9/0.05nm/rep1/step7_production_rep1.xtc \
# ./4zw9/0.05nm/rep3/step7_production_rep3.xtc \
# ./4zw9/0.05nm/rep2/step7_production_rep2.xtc \
# ./4zw9/0.1nm/rep1/step7_production_rep1.xtc \
# ./4zw9/0.1nm/rep3/step7_production_rep3.xtc \
# ./4zw9/0.1nm/rep2/step7_production_rep2.xtc \
# ./4zw9/all_common/rep1/step7_production_rep1.xtc \
# ./4zw9/all_common/rep3/step7_production_rep3.xtc \
# ./4zw9/all_common/rep2/step7_production_rep2.xtc \
# ./4zw9/baseline/rep1/step7_production_rep1.xtc \
# ./4zw9/baseline/rep3/step7_production_rep3.xtc \
# ./4zw9/baseline/rep2/step7_production_rep2.xtc \
# -o pca/4zw9_everything_all_rep.xtc
#
# gmx trjcat -f \
# ./5eqi/0.025nm/rep1/step7_production_rep1.xtc \
# ./5eqi/0.025nm/rep2/step7_production_rep2.xtc \
# ./5eqi/0.025nm/rep3/step7_production_rep3.xtc \
# ./5eqi/0.01nm/rep1/step7_production_rep1.xtc \
# ./5eqi/0.01nm/rep2/step7_production_rep2.xtc \
# ./5eqi/0.01nm/rep3/step7_production_rep3.xtc \
# ./5eqi/0.05nm/rep1/step7_production_rep1.xtc \
# ./5eqi/0.05nm/rep2/step7_production_rep2.xtc \
# ./5eqi/0.05nm/rep3/step7_production_rep3.xtc \
# ./5eqi/0.1nm/rep1/step7_production_rep1.xtc \
# ./5eqi/0.1nm/rep2/step7_production_rep2.xtc \
# ./5eqi/0.1nm/rep3/step7_production_rep3.xtc \
# ./5eqi/all_common/rep1/step7_production_rep1.xtc \
# ./5eqi/all_common/rep2/step7_production_rep2.xtc \
# ./5eqi/all_common/rep3/step7_production_rep3.xtc \
# ./5eqi/baseline/rep1/step7_production_rep1.xtc \
# ./5eqi/baseline/rep2/step7_production_rep2.xtc \
# ./5eqi/baseline/rep3/step7_production_rep3.xtc \
# -o pca/5eqi_everything_all_rep.xtc
# Out:
#                       :-) GROMACS - gmx trjcat, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
# ...

# %% [markdown]
# ## GROMACS PCA on 4ZW9

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
# SNELLIUS=/home/bas/projects/comdyn_project/snellius
#
# # 16=BB beads
# printf "16 16\n" | gmx covar -f pca/4zw9_everything_all_rep.xtc \
#     -s 4zw9/baseline/rep1/step7_production_rep1.tpr \
#     -o pca/4zw9_eigenval.everything.bb.xvg \
#     -v pca/4zw9_eigenvec.everything.bb.trr \
#     -n 4zw9/baseline/index.bb.ndx
#
#
# for item in baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm
# do
#     # Essential dynamics.
#     # Map the data on the eigenvectors/eigenvalues:
#     for i in 1 2 3
#     do
#     printf "16 16\n" | gmx anaeig \
#         -s 4zw9/baseline/rep1/step7_production_rep1.tpr \
#         -eig pca/4zw9_eigenval.everything.bb.xvg \
#         -v pca/4zw9_eigenvec.everything.bb.trr \
#         -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -2d pca/4zw9_${item}_rep${i}.everything.bb.xvg -first 1 -last 2 -n 4zw9/baseline/index.bb.ndx 2> log.txt
#     done
# done
# Out:
#                       :-) GROMACS - gmx covar, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx covar -f pca/4zw9_everything_all_rep.xtc -s 4zw9/baseline/rep1/step7_production_rep1.tpr -o pca/4zw9_eigenval.everything.bb.xvg -v pca/4zw9_eigenvec.everything.bb.trr -n 4zw9/baseline/index.bb.ndx
#
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         System) has 13512 elements
# Group     1 (        Protein) has  1010 elements
# Group     2 (      Protein-H) has  1010 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# ...

# %% [markdown]
# ## GROMACS PCA on 5EQI

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
# SNELLIUS=/home/bas/projects/comdyn_project/snellius
#
# # 16=BB beads
# printf "16 16\n" | gmx covar -f pca/5eqi_everything_all_rep.xtc \
#     -s 5eqi/baseline/rep1/step7_production_rep1.tpr \
#     -o pca/5eqi_eigenval.everything.bb.xvg \
#     -v pca/5eqi_eigenvec.everything.bb.trr \
#     -n 5eqi/baseline/index.bb.ndx
#
#
# for item in baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm
# do
#     # Essential dynamics.
#     # Map the data on the eigenvectors/eigenvalues:
#     for i in 1 2 3
#     do
#     printf "16 16\n" | gmx anaeig \
#         -s 5eqi/baseline/rep1/step7_production_rep1.tpr \
#         -eig pca/5eqi_eigenval.everything.bb.xvg \
#         -v pca/5eqi_eigenvec.everything.bb.trr \
#         -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -2d pca/5eqi_${item}_rep${i}.everything.bb.xvg -first 1 -last 2 -n 5eqi/baseline/index.bb.ndx 2> log.txt
#     done
# done
# Out:
#                       :-) GROMACS - gmx covar, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx covar -f pca/5eqi_everything_all_rep.xtc -s 5eqi/baseline/rep1/step7_production_rep1.tpr -o pca/5eqi_eigenval.everything.bb.xvg -v pca/5eqi_eigenvec.everything.bb.trr -n 5eqi/baseline/index.bb.ndx
#
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         System) has 13886 elements
# Group     1 (        Protein) has   975 elements
# Group     2 (      Protein-H) has   975 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# ...

# %% [markdown]
# # GROMACS PCA on terminal TM c-alpha helices

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
# SNELLIUS=/home/bas/projects/comdyn_project/snellius
#
# # 16=BB beads
# printf "12 12\n" | gmx covar -f pca/4zw9_everything_all_rep.xtc \
#     -s 4zw9/baseline/rep1/step7_production_rep1.tpr \
#     -o pca/4zw9_eigenval.everything.tm.xvg \
#     -v pca/4zw9_eigenvec.everything.tm.trr \
#     -n config/4zw9_distance.ndx
#
#
# for item in baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm
# do
#     # Essential dynamics.
#     # Map the data on the eigenvectors/eigenvalues:
#     for i in 1 2 3
#     do
#     printf "12 12\n" | gmx anaeig \
#         -s 4zw9/baseline/rep1/step7_production_rep1.tpr \
#         -eig pca/4zw9_eigenval.everything.tm.xvg \
#         -v pca/4zw9_eigenvec.everything.tm.trr \
#         -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -2d pca/4zw9_${item}_rep${i}.everything.tm.xvg -first 1 -last 2 -n config/4zw9_distance.ndx 2> log.txt
#     done
# done
# Out:
#                       :-) GROMACS - gmx covar, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx covar -f pca/4zw9_everything_all_rep.xtc -s 4zw9/baseline/rep1/step7_production_rep1.tpr -o pca/4zw9_eigenval.everything.tm.xvg -v pca/4zw9_eigenvec.everything.tm.trr -n config/4zw9_distance.ndx
#
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# ...

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
# SNELLIUS=/home/bas/projects/comdyn_project/snellius
#
# # 16=BB beads
# printf "12 12\n" | gmx covar -f pca/5eqi_everything_all_rep.xtc \
#     -s 5eqi/baseline/rep1/step7_production_rep1.tpr \
#     -o pca/5eqi_eigenval.everything.tm.xvg \
#     -v pca/5eqi_eigenvec.everything.tm.trr \
#     -n config/5eqi_distance.ndx
#
#
# for item in baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm
# do
#     # Essential dynamics.
#     # Map the data on the eigenvectors/eigenvalues:
#     for i in 1 2 3
#     do
#     printf "12 12\n" | gmx anaeig \
#         -s 5eqi/baseline/rep1/step7_production_rep1.tpr \
#         -eig pca/5eqi_eigenval.everything.tm.xvg \
#         -v pca/5eqi_eigenvec.everything.tm.trr \
#         -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -2d pca/5eqi_${item}_rep${i}.everything.tm.xvg -first 1 -last 2 -n config/5eqi_distance.ndx 2> log.txt
#     done
# done
# Out:
#                       :-) GROMACS - gmx covar, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx covar -f pca/5eqi_everything_all_rep.xtc -s 5eqi/baseline/rep1/step7_production_rep1.tpr -o pca/5eqi_eigenval.everything.tm.xvg -v pca/5eqi_eigenvec.everything.tm.trr -n config/5eqi_distance.ndx
#
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# ...

# %% [markdown]
# # Alternate PCA plot with legends (seaborn)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

sns.set_palette("colorblind")


def subset(x, interval=10):
    x_new = []
    for i in range(len(x)):
        if i % interval == 0:
            x_new.append(x[i])
    return x_new

plot_legend = False
dir_names = "baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm".split(" ")
label_names = ["Baseline", "No threshold", "Threshold: 0.1 nm", "Threshold: 0.05 nm", "Threshold: 0.025 nm" , "Threshold: 0.01 nm"]
names = dict(zip(dir_names, label_names))


fig, axs = plt.subplots(2, 6)
plt.rcParams["figure.figsize"] = (30, 10)
fig.subplots_adjust(hspace=0.5)
fig.subplots_adjust(wspace=0.2)

for protnr, protein in enumerate(["5eqi", "4zw9"]):

    for i, item in enumerate(dir_names):

        # Collect data from all replicates:
        df = pd.DataFrame()
        for rep in range(3):
            x,y = np.loadtxt(f"pca/{protein}_{item}_rep{rep+1}.everything.bb.xvg",comments=["@", "#"],unpack=True)
            data = {"x" : subset(x), 
                    "y": subset(y), 
                    "Replicate" : "rep " + str(rep+1) }
            df = pd.concat([df, pd.DataFrame(data)])

        # Plot everything per threshold:
        label = names[item]

        sns.kdeplot(data=df, x="x", y="y", levels=5, thresh=.2, ax=axs[protnr][i], hue="Replicate", legend=(i==0))

        # Set some plot parameters:
        # Grab start point:
        x1 = df[df["Replicate"] == "rep 1"]['x'][0]
        y1 = df[df["Replicate"] == "rep 1"]['y'][0]
        axs[protnr][i].plot(x1, y1, "x", c="black")

        # X/Y limits:
        axs[protnr][i].set_xlim((-4, 4))
        axs[protnr][i].set_ylim((-4, 4))
        axs[protnr][i].set_xlabel("Projection on eigenvector 1 (nm)")
        axs[protnr][i].set_ylabel("Projection on eigenvector 2 (nm)")
        

for protnr, protein in enumerate(["5eqi", "4zw9"]):
    for i, item in enumerate(dir_names):
        label = names[item]
        if i == 0:
            if protnr == 0:
                axs[0][i].set_title(f"Essential dynamics on backbone of GLUT1\n(PDB-ID: 5EQI)\n\n{label}")
            else:
                axs[1][i].set_title(f"Essential dynamics on backbone of GLUT3\n(PDB-ID: 4ZW9)\n\n{label})")
        else:
            if protnr == 0:
                axs[0][i].set_title(f"\n\n{label}")
            else:
                axs[1][i].set_title(f"\n\n{label})")

# %% [markdown]
# # TM helices

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def subset(x, interval=10):
    x_new = []
    for i in range(len(x)):
        if i % interval == 0:
            x_new.append(x[i])
    return x_new



plot_legend = False
dir_names = "baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm".split(" ")
label_names = ["Baseline", "No threshold", "Threshold: 0.1 nm", "Threshold: 0.05 nm", "Threshold: 0.025 nm" , "Threshold: 0.01 nm"]
names = dict(zip(dir_names, label_names))


fig, axs = plt.subplots(2, 6)
plt.rcParams["figure.figsize"] = (30, 10)
fig.subplots_adjust(hspace=0.5)
fig.subplots_adjust(wspace=0.2)
for protnr, protein in enumerate(["4zw9", "5eqi"]):

    for i, item in enumerate(dir_names):
        # Collect data from all replicates:
        df = pd.DataFrame()
        for rep in range(3):
            x,y = np.loadtxt(f"pca/{protein}_{item}_rep{rep+1}.everything.tm.xvg",comments=["@", "#"],unpack=True)
            data = {"x" : subset(x), 
                    "y": subset(y), 
                    "Replicate" : "rep " + str(rep+1) }
            df = pd.concat([df, pd.DataFrame(data)])

        # Plot everything per threshold:
        label = names[item]
        
        sns.kdeplot(data=df, x="x", y="y", levels=5, thresh=.2, ax=axs[protnr][i], hue="Replicate", legend=(i==0))

        # Set some plot parameters:
        # Grab start point:
        x1 = df[df["Replicate"] == "rep 1"]['x'][0]
        y1 = df[df["Replicate"] == "rep 1"]['y'][0]
        axs[protnr][i].plot(x1, y1, "x", c="black")

        # X/Y limits:
        axs[protnr][i].set_xlim((-2.5, 2.5))
        axs[protnr][i].set_ylim((-2.5, 2.5))
        axs[protnr][i].set_xlabel("Projection on eigenvector 1 (nm)")
        axs[protnr][i].set_ylabel("Projection on eigenvector 2 (nm)")
        
        # Title:
        if i == 0:      
            axs[protnr][i].set_title(f"Essential dynamics on AA selection\n(PDB-ID: {protein.upper()})\n\n{label}")
        else:
            axs[protnr][i].set_title(f"{label}")
