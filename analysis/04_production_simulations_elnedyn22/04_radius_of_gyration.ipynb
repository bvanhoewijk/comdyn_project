# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
#
# mkdir -p gr
# # GROUP 16 is the Backbone
# ####################### GR 4ZW9
# for item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common
# do
#     # Gyrate
#     for i in 1 2 3
#     do
#     printf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \
#         -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -n 4zw9/baseline/index.bb.ndx\
#         -o gr/4zw9_${item}_rep${i}.xvg
#     done
# done
#
# ##### No rubber (has only 1 rep)
# i=1
# item="no_rubber"
# printf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \
#     -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \
#     -n 4zw9/baseline/index.bb.ndx\
#     -o gr/4zw9_${item}_rep${i}.xvg
#
# ####################### GR 5EQI
# for item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common
# do
#     # Gyrate
#     for i in 1 2 3
#     do
#     printf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \
#         -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -n 5eqi/baseline/index.bb.ndx\
#         -o gr/5eqi_${item}_rep${i}.xvg
#     done
# done
#
# ##### No rubber (has only 1 rep)
# i=1
# item="no_rubber"
# printf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \
#     -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \
#     -n 5eqi/baseline/index.bb.ndx\
#     -o gr/5eqi_${item}_rep${i}.xvg
# Out:
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep1/step7_production_rep1.tpr -f 4zw9/baseline/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_baseline_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/baseline/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/baseline/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep2/step7_production_rep2.tpr -f 4zw9/baseline/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_baseline_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/baseline/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/baseline/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep3/step7_production_rep3.tpr -f 4zw9/baseline/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_baseline_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/baseline/rep3/step7_production_rep3.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/baseline/rep3/step7_production_rep3.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep1/step7_production_rep1.tpr -f 4zw9/0.1nm/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.1nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.1nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.1nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep2/step7_production_rep2.tpr -f 4zw9/0.1nm/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.1nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.1nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.1nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep3/step7_production_rep3.tpr -f 4zw9/0.1nm/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.1nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.1nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.1nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep1/step7_production_rep1.tpr -f 4zw9/0.05nm/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.05nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.05nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.05nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep2/step7_production_rep2.tpr -f 4zw9/0.05nm/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.05nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.05nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.05nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep3/step7_production_rep3.tpr -f 4zw9/0.05nm/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.05nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.05nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.05nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep1/step7_production_rep1.tpr -f 4zw9/0.025nm/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.025nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.025nm/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.025nm/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep2/step7_production_rep2.tpr -f 4zw9/0.025nm/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.025nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.025nm/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.025nm/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep3/step7_production_rep3.tpr -f 4zw9/0.025nm/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.025nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.025nm/rep3/step7_production_rep3.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.025nm/rep3/step7_production_rep3.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep1/step7_production_rep1.tpr -f 4zw9/0.01nm/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.01nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.01nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.01nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep2/step7_production_rep2.tpr -f 4zw9/0.01nm/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.01nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.01nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.01nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep3/step7_production_rep3.tpr -f 4zw9/0.01nm/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_0.01nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/0.01nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/0.01nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep1/step7_production_rep1.tpr -f 4zw9/all_common/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_all_common_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/all_common/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/all_common/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep2/step7_production_rep2.tpr -f 4zw9/all_common/rep2/step7_production_rep2.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_all_common_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/all_common/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/all_common/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep3/step7_production_rep3.tpr -f 4zw9/all_common/rep3/step7_production_rep3.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_all_common_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/all_common/rep3/step7_production_rep3.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/all_common/rep3/step7_production_rep3.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/no_rubber/rep1/step7_production_rep1.tpr -f 4zw9/no_rubber/rep1/step7_production_rep1.xtc -n 4zw9/baseline/index.bb.ndx -o gr/4zw9_no_rubber_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '4zw9/no_rubber/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '4zw9/no_rubber/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '4zw9/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep1/step7_production_rep1.tpr -f 5eqi/baseline/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_baseline_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/baseline/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/baseline/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep2/step7_production_rep2.tpr -f 5eqi/baseline/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_baseline_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/baseline/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/baseline/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep3/step7_production_rep3.tpr -f 5eqi/baseline/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_baseline_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/baseline/rep3/step7_production_rep3.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/baseline/rep3/step7_production_rep3.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep1/step7_production_rep1.tpr -f 5eqi/0.1nm/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.1nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.1nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.1nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep2/step7_production_rep2.tpr -f 5eqi/0.1nm/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.1nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.1nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.1nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep3/step7_production_rep3.tpr -f 5eqi/0.1nm/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.1nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.1nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.1nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep1/step7_production_rep1.tpr -f 5eqi/0.05nm/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.05nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.05nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.05nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep2/step7_production_rep2.tpr -f 5eqi/0.05nm/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.05nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.05nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.05nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep3/step7_production_rep3.tpr -f 5eqi/0.05nm/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.05nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.05nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.05nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep1/step7_production_rep1.tpr -f 5eqi/0.025nm/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.025nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.025nm/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.025nm/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep2/step7_production_rep2.tpr -f 5eqi/0.025nm/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.025nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.025nm/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.025nm/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep3/step7_production_rep3.tpr -f 5eqi/0.025nm/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.025nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# ...
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep1/step7_production_rep1.tpr -f 5eqi/0.01nm/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.01nm_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.01nm/rep1/step7_production_rep1.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.01nm/rep1/step7_production_rep1.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep2/step7_production_rep2.tpr -f 5eqi/0.01nm/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.01nm_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.01nm/rep2/step7_production_rep2.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.01nm/rep2/step7_production_rep2.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep3/step7_production_rep3.tpr -f 5eqi/0.01nm/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_0.01nm_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/0.01nm/rep3/step7_production_rep3.tpr' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/0.01nm/rep3/step7_production_rep3.xtc' does not exist or is not
#     accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep1/step7_production_rep1.tpr -f 5eqi/all_common/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_all_common_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/all_common/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/all_common/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep2/step7_production_rep2.tpr -f 5eqi/all_common/rep2/step7_production_rep2.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_all_common_rep2.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/all_common/rep2/step7_production_rep2.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/all_common/rep2/step7_production_rep2.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep3/step7_production_rep3.tpr -f 5eqi/all_common/rep3/step7_production_rep3.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_all_common_rep3.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/all_common/rep3/step7_production_rep3.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/all_common/rep3/step7_production_rep3.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/04_production_simulations_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/no_rubber/rep1/step7_production_rep1.tpr -f 5eqi/no_rubber/rep1/step7_production_rep1.xtc -n 5eqi/baseline/index.bb.ndx -o gr/5eqi_no_rubber_rep1.xvg
#
#
# -------------------------------------------------------
# Program:     gmx gyrate, version 2023.3
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -s
#     File '5eqi/no_rubber/rep1/step7_production_rep1.tpr' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -f
#     File '5eqi/no_rubber/rep1/step7_production_rep1.xtc' does not exist or is
#     not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -n
#     File '5eqi/baseline/index.bb.ndx' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'source /usr/local/gromacs/bin/GMXRC\n\nmkdir -p gr\n# GROUP 16 is the Backbone\n####################### GR 4ZW9\nfor item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common\ndo\n    # Gyrate\n    for i in 1 2 3\n    do\n    printf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \\\n        -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \\\n        -n 4zw9/baseline/index.bb.ndx\\\n        -o gr/4zw9_${item}_rep${i}.xvg\n    done\ndone\n\n##### No rubber (has only 1 rep)\ni=1\nitem="no_rubber"\nprintf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \\\n    -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \\\n    -n 4zw9/baseline/index.bb.ndx\\\n    -o gr/4zw9_${item}_rep${i}.xvg\n\n####################### GR 5EQI\nfor item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common\ndo\n    # Gyrate\n    for i in 1 2 3\n    do\n    printf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \\\n        -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \\\n        -n 5eqi/baseline/index.bb.ndx\\\n        -o gr/5eqi_${item}_rep${i}.xvg\n    done\ndone\n\n##### No rubber (has only 1 rep)\ni=1\nitem="no_rubber"\nprintf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \\\n    -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \\\n    -n 5eqi/baseline/index.bb.ndx\\\n    -o gr/5eqi_${item}_rep${i}.xvg\n')
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/IPython/core/magics/script.py:154, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     152 else:
#     153     line = script
# --> 154 return self.shebang(line, cell)
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/IPython/core/magics/script.py:314, in ScriptMagics.shebang(self, line, cell)
#     309 if args.raise_error and p.returncode != 0:
#     310     # If we get here and p.returncode is still None, we must have
#     311     # killed it but not yet seen its return code. We don't wait for it,
#     312     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     313     rc = p.returncode or -9
# --> 314     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'source /usr/local/gromacs/bin/GMXRC\n\nmkdir -p gr\n# GROUP 16 is the Backbone\n####################### GR 4ZW9\nfor item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common\ndo\n    # Gyrate\n    for i in 1 2 3\n    do\n    printf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \\\n        -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \\\n        -n 4zw9/baseline/index.bb.ndx\\\n        -o gr/4zw9_${item}_rep${i}.xvg\n    done\ndone\n\n##### No rubber (has only 1 rep)\ni=1\nitem="no_rubber"\nprintf "16" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \\\n    -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \\\n    -n 4zw9/baseline/index.bb.ndx\\\n    -o gr/4zw9_${item}_rep${i}.xvg\n\n####################### GR 5EQI\nfor item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common\ndo\n    # Gyrate\n    for i in 1 2 3\n    do\n    printf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \\\n        -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \\\n        -n 5eqi/baseline/index.bb.ndx\\\n        -o gr/5eqi_${item}_rep${i}.xvg\n    done\ndone\n\n##### No rubber (has only 1 rep)\ni=1\nitem="no_rubber"\nprintf "16" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \\\n    -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \\\n    -n 5eqi/baseline/index.bb.ndx\\\n    -o gr/5eqi_${item}_rep${i}.xvg\n'' returned non-zero exit status 1.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

sns.set_palette("colorblind")

dir_names = "baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm no_rubber".split(" ")
label_names = ["Baseline", "No threshold", "Threshold: 0.1 nm", "Threshold: 0.05 nm", "Threshold: 0.025 nm" , "Threshold: 0.01 nm"]

df = pd.DataFrame()
for protein in ["5eqi", "4zw9"]:
    for threshold in dir_names:
        for i in range(3):
            path = f"gr/{protein}_{threshold}_rep{i+1}.xvg"
            if not os.path.isfile(path):
                continue

            x, y, rg_x, rg_y, rg_z = np.loadtxt(path,comments=["@", "#"],unpack=True)
            res = pd.DataFrame({
                "time" : x,
                "rg_all" : y,
                "rg_x"   : rg_x,
                "rg_y"   : rg_y,
                "rg_z"   : rg_z,
                "replicate" : f"rep {i+1}",
                "protein"   : protein,
                "threshold" : threshold,
            })
            df = pd.concat([df, res])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
plt.rcParams["figure.figsize"] = (8, 5)
ax = sns.boxplot(data=df, x="threshold", y="rg_all", hue="protein")
ax.set_ylabel("Rg (nm)")
ax.set_xlabel(None)
ax.set_title("Radius of gyration calculated on backbone")
ax.tick_params(axis='x', labelrotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.rcParams["figure.figsize"] = (8, 5)
# ----> 2 ax = sns.boxplot(data=df, x="threshold", y="rg_all", hue="protein")
#       3 ax.set_ylabel("Rg (nm)")
#       4 ax.set_xlabel(None)
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
#    1603         legend=legend,
#    1604     )
#    1606     if ax is None:
#    1607         ax = plt.gca()
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `threshold` for `x`. An entry with this name does not appear in `data`.

# %%
plt.rcParams["figure.figsize"] = (8, 5)
ax = sns.boxplot(data=df[df["protein"] == "5eqi"], x="threshold", y="rg_all", hue="replicate")
ax.set_ylabel("Rg (nm)")
ax.set_xlabel("Threshold")
ax.set_title("Protein: 5EQI\nRadius of gyration calculated on backbone (overall)")
ax.tick_params(axis='x', labelrotation=45)
plt.figure()

ax = sns.boxplot(data=df[df["protein"] == "4zw9"], x="threshold", y="rg_all", hue="replicate")
ax.set_ylabel("Rg (nm)")
ax.set_xlabel("Threshold")
ax.set_title("Protein: 4ZW9\nRadius of gyration calculated on backbone (overall)")
ax.tick_params(axis='x', labelrotation=45)
plt.figure()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.rcParams["figure.figsize"] = (8, 5)
# ----> 2 ax = sns.boxplot(data=df[df["protein"] == "5eqi"], x="threshold", y="rg_all", hue="replicate")
#       3 ax.set_ylabel("Rg (nm)")
#       4 ax.set_xlabel("Threshold")
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/miniconda3/envs/md_production/lib/python3.12/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'protein'

# %%
# %%bash
# source /usr/local/gromacs/bin/GMXRC
#
# # GROUP 16 is the Backbone
# ####################### GR 4ZW9
# for item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common no_rubber
# do
#     # Gyrate
#     for i in 1 2 3
#     do
#     tpr_file=4zw9/${item}/rep${i}/step7_production_rep${i}.tpr
#     if [ ! -f ${tpr_file} ]; then
#         echo "File ${tpr_file} does not exist. Continuing with next file."
#         continue
#     fi
#     printf "14" | gmx gyrate -s 4zw9/${item}/rep${i}/step7_production_rep${i}.tpr \
#         -f 4zw9/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -n config/4zw9_distance.ndx\
#         -o gr/4zw9_${item}_tmout_rep${i}.xvg
#     done
# done
#
# ####################### GR 5EQI
# for item in baseline 0.1nm 0.05nm 0.025nm 0.01nm all_common no_rubber
# do
#     # Gyrate
#     for i in 1 2 3
#     do
#     tpr_file=5eqi/${item}/rep${i}/step7_production_rep${i}.tpr
#     if [ ! -f ${tpr_file} ]; then
#         echo "File ${tpr_file} does not exist. Continuing with next file."
#         continue
#     fi
#     printf "14" | gmx gyrate -s 5eqi/${item}/rep${i}/step7_production_rep${i}.tpr \
#         -f 5eqi/${item}/rep${i}/step7_production_rep${i}.xtc \
#         -n config/5eqi_distance.ndx\
#         -o gr/5eqi_${item}_tmout_rep${i}.xvg
#     done
# done
# Out:
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep1/step7_production_rep1.tpr -f 4zw9/baseline/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_baseline_tmout_rep1.xvg
#
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "You Crashed Into the Swamps" (Silicon Graphics)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep2/step7_production_rep2.tpr -f 4zw9/baseline/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_baseline_tmout_rep2.xvg
#
# Reading file 4zw9/baseline/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/baseline/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Hang On to Your Ego" (F. Black)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/baseline/rep3/step7_production_rep3.tpr -f 4zw9/baseline/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_baseline_tmout_rep3.xvg
#
# Reading file 4zw9/baseline/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/baseline/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I Should Be the Pimp Of the Year" (Urban Dance Squad)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep1/step7_production_rep1.tpr -f 4zw9/0.1nm/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.1nm_tmout_rep1.xvg
#
# Reading file 4zw9/0.1nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.1nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I Should Be the Pimp Of the Year" (Urban Dance Squad)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep2/step7_production_rep2.tpr -f 4zw9/0.1nm/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.1nm_tmout_rep2.xvg
#
# Reading file 4zw9/0.1nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.1nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "To survive science you have to become science." (Gerrit Groenhof)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.1nm/rep3/step7_production_rep3.tpr -f 4zw9/0.1nm/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.1nm_tmout_rep3.xvg
#
# Reading file 4zw9/0.1nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.1nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I'm Gonna Get Medieval On Your Ass" (Pulp Fiction)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep1/step7_production_rep1.tpr -f 4zw9/0.05nm/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.05nm_tmout_rep1.xvg
#
# Reading file 4zw9/0.05nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.05nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I'm Gonna Get Medieval On Your Ass" (Pulp Fiction)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep2/step7_production_rep2.tpr -f 4zw9/0.05nm/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.05nm_tmout_rep2.xvg
#
# Reading file 4zw9/0.05nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.05nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "The time for theory is over" (J. Hajdu)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.05nm/rep3/step7_production_rep3.tpr -f 4zw9/0.05nm/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.05nm_tmout_rep3.xvg
#
# Reading file 4zw9/0.05nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.05nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "In physics, you don't have to go around making trouble for yourself. Nature does it for you." (Frank Wilczek)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep1/step7_production_rep1.tpr -f 4zw9/0.025nm/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.025nm_tmout_rep1.xvg
#
# Reading file 4zw9/0.025nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.025nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "In physics, you don't have to go around making trouble for yourself. Nature does it for you." (Frank Wilczek)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep2/step7_production_rep2.tpr -f 4zw9/0.025nm/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.025nm_tmout_rep2.xvg
#
# Reading file 4zw9/0.025nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.025nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I Should Be the Pimp Of the Year" (Urban Dance Squad)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.025nm/rep3/step7_production_rep3.tpr -f 4zw9/0.025nm/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.025nm_tmout_rep3.xvg
#
# Reading file 4zw9/0.025nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.025nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I Should Be the Pimp Of the Year" (Urban Dance Squad)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep1/step7_production_rep1.tpr -f 4zw9/0.01nm/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.01nm_tmout_rep1.xvg
#
# Reading file 4zw9/0.01nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.01nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I've Got Two Turntables and a Microphone" (B. Hansen)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep2/step7_production_rep2.tpr -f 4zw9/0.01nm/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.01nm_tmout_rep2.xvg
#
# Reading file 4zw9/0.01nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.01nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I've Got Two Turntables and a Microphone" (B. Hansen)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/0.01nm/rep3/step7_production_rep3.tpr -f 4zw9/0.01nm/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_0.01nm_tmout_rep3.xvg
#
# Reading file 4zw9/0.01nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/0.01nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Not to get technical... but according to chemistry, alcohol is a solution." (Anonymous)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep1/step7_production_rep1.tpr -f 4zw9/all_common/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_all_common_tmout_rep1.xvg
#
# Reading file 4zw9/all_common/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/all_common/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "My Heart is Just a Muscle In a Cavity" (F. Black)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep2/step7_production_rep2.tpr -f 4zw9/all_common/rep2/step7_production_rep2.xtc -n config/4zw9_distance.ndx -o gr/4zw9_all_common_tmout_rep2.xvg
#
# Reading file 4zw9/all_common/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/all_common/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "My Heart is Just a Muscle In a Cavity" (F. Black)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/all_common/rep3/step7_production_rep3.tpr -f 4zw9/all_common/rep3/step7_production_rep3.xtc -n config/4zw9_distance.ndx -o gr/4zw9_all_common_tmout_rep3.xvg
#
# Reading file 4zw9/all_common/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/all_common/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Why, how now, Claudio ! Whence Comes this Restraint ?" (Lucio in Measure for measure, Act 1, Scene 4, William Shakespeare)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 4zw9/no_rubber/rep1/step7_production_rep1.tpr -f 4zw9/no_rubber/rep1/step7_production_rep1.xtc -n config/4zw9_distance.ndx -o gr/4zw9_no_rubber_tmout_rep1.xvg
#
# Reading file 4zw9/no_rubber/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 4zw9/no_rubber/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame       2000 time 2000000.000
#
# GROMACS reminds you: "I tend to consider myself as a scientist." (Emmanuelle Charpentier, when asked about the importance of two women sharing the Nobel Prize for Chemistry)
# Selected 14: 'TM_OUT'
# File 4zw9/no_rubber/rep2/step7_production_rep2.tpr does not exist. Continuing with next file.
# File 4zw9/no_rubber/rep3/step7_production_rep3.tpr does not exist. Continuing with next file.
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep1/step7_production_rep1.tpr -f 5eqi/baseline/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_baseline_tmout_rep1.xvg
#
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/baseline/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "If You Don't Like Cool Quotes Check Your GMXRC File" (Your Sysadmin)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep2/step7_production_rep2.tpr -f 5eqi/baseline/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_baseline_tmout_rep2.xvg
#
# Reading file 5eqi/baseline/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/baseline/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Don't Grumble, Give a Whistle !" (Monty Python)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/baseline/rep3/step7_production_rep3.tpr -f 5eqi/baseline/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_baseline_tmout_rep3.xvg
#
# Reading file 5eqi/baseline/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/baseline/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Don't Grumble, Give a Whistle !" (Monty Python)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep1/step7_production_rep1.tpr -f 5eqi/0.1nm/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.1nm_tmout_rep1.xvg
#
# Reading file 5eqi/0.1nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.1nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "I'll Match Your DNA" (Red Hot Chili Peppers)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep2/step7_production_rep2.tpr -f 5eqi/0.1nm/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.1nm_tmout_rep2.xvg
#
# Reading file 5eqi/0.1nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.1nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "It's just B I O L O G Y, can't you see?" (Joe Jackson)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.1nm/rep3/step7_production_rep3.tpr -f 5eqi/0.1nm/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.1nm_tmout_rep3.xvg
#
# Reading file 5eqi/0.1nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.1nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "If at one time or another I have brushed a few colleagues the wrong way, I must apologize: I had not realized that they were covered with fur." (Edwin Chargaff)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep1/step7_production_rep1.tpr -f 5eqi/0.05nm/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.05nm_tmout_rep1.xvg
#
# Reading file 5eqi/0.05nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.05nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "If at one time or another I have brushed a few colleagues the wrong way, I must apologize: I had not realized that they were covered with fur." (Edwin Chargaff)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep2/step7_production_rep2.tpr -f 5eqi/0.05nm/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.05nm_tmout_rep2.xvg
#
# Reading file 5eqi/0.05nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.05nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Louis Pasteur's theory of germs is ridiculous fiction." (Pierre Pachet, Professor of Physiology at Toulouse, 1872)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.05nm/rep3/step7_production_rep3.tpr -f 5eqi/0.05nm/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.05nm_tmout_rep3.xvg
#
# Reading file 5eqi/0.05nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.05nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Louis Pasteur's theory of germs is ridiculous fiction." (Pierre Pachet, Professor of Physiology at Toulouse, 1872)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep1/step7_production_rep1.tpr -f 5eqi/0.025nm/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.025nm_tmout_rep1.xvg
#
# Reading file 5eqi/0.025nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.025nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "A Pretty Village Burning Makes a Pretty Fire" (David Sandstrom)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep2/step7_production_rep2.tpr -f 5eqi/0.025nm/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.025nm_tmout_rep2.xvg
#
# Reading file 5eqi/0.025nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.025nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "The Stingrays Must Be Fat This Year" (Red Hot Chili Peppers)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.025nm/rep3/step7_production_rep3.tpr -f 5eqi/0.025nm/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.025nm_tmout_rep3.xvg
#
# Reading file 5eqi/0.025nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.025nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "The Stingrays Must Be Fat This Year" (Red Hot Chili Peppers)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep1/step7_production_rep1.tpr -f 5eqi/0.01nm/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.01nm_tmout_rep1.xvg
#
# Reading file 5eqi/0.01nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.01nm/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "If you want to save your child from polio, you can pray or you can inoculate... choose science." (Carl Sagan)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep2/step7_production_rep2.tpr -f 5eqi/0.01nm/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.01nm_tmout_rep2.xvg
#
# Reading file 5eqi/0.01nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.01nm/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "It Was My Pleasure" (Pulp Fiction)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/0.01nm/rep3/step7_production_rep3.tpr -f 5eqi/0.01nm/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_0.01nm_tmout_rep3.xvg
#
# Reading file 5eqi/0.01nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/0.01nm/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "It Was My Pleasure" (Pulp Fiction)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep1/step7_production_rep1.tpr -f 5eqi/all_common/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_all_common_tmout_rep1.xvg
#
# Reading file 5eqi/all_common/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/all_common/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "All Beauty Must Die" (Nick Cave)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep2/step7_production_rep2.tpr -f 5eqi/all_common/rep2/step7_production_rep2.xtc -n config/5eqi_distance.ndx -o gr/5eqi_all_common_tmout_rep2.xvg
#
# Reading file 5eqi/all_common/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/all_common/rep2/step7_production_rep2.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Nothing shocks me. I'm a scientist." (Harrison Ford as Indiana Jones)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/all_common/rep3/step7_production_rep3.tpr -f 5eqi/all_common/rep3/step7_production_rep3.xtc -n config/5eqi_distance.ndx -o gr/5eqi_all_common_tmout_rep3.xvg
#
# Reading file 5eqi/all_common/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/all_common/rep3/step7_production_rep3.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame      10000 time 2000000.000
#
# GROMACS reminds you: "Nothing shocks me. I'm a scientist." (Harrison Ford as Indiana Jones)
# Selected 14: 'TM_OUT'
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s 5eqi/no_rubber/rep1/step7_production_rep1.tpr -f 5eqi/no_rubber/rep1/step7_production_rep1.xtc -n config/5eqi_distance.ndx -o gr/5eqi_no_rubber_tmout_rep1.xvg
#
# Reading file 5eqi/no_rubber/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Reading file 5eqi/no_rubber/rep1/step7_production_rep1.tpr, VERSION 2023.3-EasyBuild_4.9.0 (single precision)
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Last frame       2000 time 2000000.000
#
# GROMACS reminds you: "Does college pay? They do if you are a good open-field runner." (Will Rogers)
# Selected 14: 'TM_OUT'
# File 5eqi/no_rubber/rep2/step7_production_rep2.tpr does not exist. Continuing with next file.
# File 5eqi/no_rubber/rep3/step7_production_rep3.tpr does not exist. Continuing with next file.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

dir_names = "baseline all_common 0.1nm 0.05nm 0.025nm 0.01nm no_rubber".split(" ")
label_names = ["Baseline", "No threshold", "Threshold: 0.1 nm", "Threshold: 0.05 nm", "Threshold: 0.025 nm" , "Threshold: 0.01 nm"]

df_in = pd.DataFrame()
for protein in ["5eqi", "4zw9"]:
    for threshold in dir_names:
        for i in range(3):
            path = f"gr/{protein}_{threshold}_tmin_rep{i+1}.xvg"
            if not os.path.isfile(path):
                continue

            x, y, rg_x, rg_y, rg_z = np.loadtxt(path,comments=["@", "#"],unpack=True)
            res = pd.DataFrame({
                "time" : x,
                "rg_all" : y,
                "rg_x"   : rg_x,
                "rg_y"   : rg_y,
                "rg_z"   : rg_z,
                "replicate" : f"rep {i+1}",
                "protein"   : protein,
                "threshold" : threshold,
            })
            df_in = pd.concat([df_in, res])

df_out = pd.DataFrame()
for protein in ["5eqi", "4zw9"]:
    for threshold in dir_names:
        for i in range(3):
            path = f"gr/{protein}_{threshold}_tmout_rep{i+1}.xvg"
            if not os.path.isfile(path):
                continue

            x, y, rg_x, rg_y, rg_z = np.loadtxt(path,comments=["@", "#"],unpack=True)
            res = pd.DataFrame({
                "time" : x,
                "rg_all" : y,
                "rg_x"   : rg_x,
                "rg_y"   : rg_y,
                "rg_z"   : rg_z,
                "replicate" : f"rep {i+1}",
                "protein"   : protein,
                "threshold" : threshold,
            })
            df_out = pd.concat([df_out, res])

df_out
# Out:
#            time   rg_all      rg_x     rg_y     rg_z replicate protein  \
# 0           0.0  1.41482  1.252950  1.03090  1.17080     rep 1    5eqi
# 1         200.0  1.41548  1.254300  1.03869  1.16406     rep 1    5eqi
# 2         400.0  1.40960  1.248800  1.05052  1.14492     rep 1    5eqi
# 3         600.0  1.40481  1.234400  1.04416  1.15454     rep 1    5eqi
# 4         800.0  1.42773  1.268350  1.04752  1.17081     rep 1    5eqi
# ...         ...      ...       ...      ...      ...       ...     ...
# 1996  1996000.0  1.56458  0.916454  1.39468  1.45285     rep 1    4zw9
# 1997  1997000.0  1.57154  0.907180  1.38328  1.48427     rep 1    4zw9
# 1998  1998000.0  1.55720  0.896725  1.38935  1.45442     rep 1    4zw9
# 1999  1999000.0  1.57709  0.932539  1.38745  1.47640     rep 1    4zw9
# 2000  2000000.0  1.56195  0.956379  1.35797  1.45623     rep 1    4zw9
#
#       threshold
# 0      baseline
# 1      baseline
# 2      baseline
# 3      baseline
# 4      baseline
# ...         ...
# 1996  no_rubber
# 1997  no_rubber
# 1998  no_rubber
# 1999  no_rubber
# 2000  no_rubber
#
# [364038 rows x 8 columns]

# %%
fig, axs = plt.subplots(1, 2)
plt.rcParams["figure.figsize"] = (10, 4)

axs[0].axhline(1.39, c="orange", alpha=0.6)
axs[0].axhline(1.55, c="darkblue", alpha=0.6)
sns.boxplot(data=df_in, x="threshold", y="rg_all", hue="protein", ax=axs[0])
axs[0].set_ylabel("Rg (nm)")
axs[0].set_xlabel("Threshold")
axs[0].set_title("Radius of gyration TM_IN")

axs[1].axhline(1.5, c="orange", alpha=0.6)
axs[1].axhline(1.41, c="darkblue", alpha=0.6)
sns.boxplot(data=df_out, x="threshold", y="rg_all", hue="protein", ax=axs[1])
axs[1].set_ylabel("Rg (nm)")
axs[1].set_xlabel("Threshold")
axs[1].set_title("Radius of gyration TM_OUT")

axs[0].tick_params(axis='x', labelrotation=45)
axs[1].tick_params(axis='x', labelrotation=45)

# %%
# %%bash
#
# ############### TM outwards
# printf "14" | gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb \
#     -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb \
#     -n config/4zw9_distance.ndx\
#     -o gr/4zw9_crystal_tmout.xvg
#
# printf "14" | gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb \
#     -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb \
#     -n config/5eqi_distance.ndx \
#     -o gr/5eqi_crystal_tmout.xvg
#
# ############### TM inwards
# printf "13" | gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb \
#     -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb \
#     -n config/4zw9_distance.ndx\
#     -o gr/4zw9_crystal_tmin.xvg
#
# printf "13" | gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb \
#     -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb \
#     -n config/5eqi_distance.ndx \
#     -o gr/5eqi_crystal_tmin.xvg
# Out:
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb -n config/4zw9_distance.ndx -o gr/4zw9_crystal_tmout.xvg
#
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Reading frame       0 time    0.000   b file
# Back Off! I just backed up gr/4zw9_crystal_tmout.xvg to gr/#4zw9_crystal_tmout.xvg.2#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
#  '', 1010 atoms
# Last frame          0 time    0.000
#
# GROMACS reminds you: "I tend to consider myself as a scientist." (Emmanuelle Charpentier, when asked about the importance of two women sharing the Nobel Prize for Chemistry)
#
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb -n config/5eqi_distance.ndx -o gr/5eqi_crystal_tmout.xvg
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 14: 'TM_OUT'
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Reading frame       0 time    0.000   b file
# Back Off! I just backed up gr/5eqi_crystal_tmout.xvg to gr/#5eqi_crystal_tmout.xvg.2#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
#  '', 975 atoms
# Last frame          0 time    0.000
#
# GROMACS reminds you: "I tend to consider myself as a scientist." (Emmanuelle Charpentier, when asked about the importance of two women sharing the Nobel Prize for Chemistry)
#
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023580519/4zw9_proa.cg.pdb -n config/4zw9_distance.ndx -o gr/4zw9_crystal_tmin.xvg
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 14: 'TM_OUT'
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Reading frame       0 time    0.000   b file
# Back Off! I just backed up gr/4zw9_crystal_tmin.xvg to gr/#4zw9_crystal_tmin.xvg.1#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
#  '', 1010 atoms
# Last frame          0 time    0.000
#
# GROMACS reminds you: "I tend to consider myself as a scientist." (Emmanuelle Charpentier, when asked about the importance of two women sharing the Nobel Prize for Chemistry)
#
#                       :-) GROMACS - gmx gyrate, 2023.3 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22
# Command line:
#   gmx gyrate -s /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb -f /home/bas/projects/comdyn_project/analysis/02_angstrom_benchmark_elnedyn22/charmm-gui-1023500892/5eqi_proa.cg.pdb -n config/5eqi_distance.ndx -o gr/5eqi_crystal_tmin.xvg
#
# Group     0 (         TM1_in) has    10 elements
# Group     1 (        TM1_out) has    10 elements
# Group     2 (         TM2_in) has    10 elements
# Group     3 (        TM2_out) has    10 elements
# Group     4 (         TM5_in) has    10 elements
# Group     5 (        TM5_out) has    10 elements
# Group     6 (         TM7_in) has    10 elements
# Group     7 (        TM7_out) has    10 elements
# Group     8 (         TM8_in) has    10 elements
# Group     9 (        TM8_out) has    10 elements
# Group    10 (        TM11_in) has    10 elements
# Group    11 (       TM11_out) has    10 elements
# Group    12 ( all_tm_helices) has   120 elements
# Group    13 (          TM_IN) has    60 elements
# Group    14 (         TM_OUT) has    60 elements
# Reading frame       0 time    0.000   b file
# Back Off! I just backed up gr/5eqi_crystal_tmin.xvg to gr/#5eqi_crystal_tmin.xvg.1#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
#  '', 975 atoms
# Last frame          0 time    0.000
#
# GROMACS reminds you: "I tend to consider myself as a scientist." (Emmanuelle Charpentier, when asked about the importance of two women sharing the Nobel Prize for Chemistry)
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 13: 'TM_IN'
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 13: 'TM_IN'

# %% [markdown]
# ```bash
# tail -n1 gr/*_crystal_tm*.xvg
# ```
# ```text
# ==> gr/4zw9_crystal_tmin.xvg <==
#          0     1.39106     1.16515     1.30724    0.896452
#
# ==> gr/4zw9_crystal_tmout.xvg <==
#          0     1.54373     1.27943     1.32782     1.16881
#
# ==> gr/5eqi_crystal_tmin.xvg <==
#          0     1.55984     1.13624      1.1641     1.48998
#
# ==> gr/5eqi_crystal_tmout.xvg <==
#          0      1.4139     1.24738     1.03962     1.16683
# ```
